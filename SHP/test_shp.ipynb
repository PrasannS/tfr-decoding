# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer
import torch
from datasets import load_dataset
import pandas as pd

device = 'cuda:1' # if you have a GPU

# %%
tokenizer = T5Tokenizer.from_pretrained('stanfordnlp/SteamSHP-flan-t5-xl')
model = T5ForConditionalGeneration.from_pretrained('stanfordnlp/SteamSHP-flan-t5-xl').to(device)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def get_reward_single(inpdict, tok, mod):
    template = "POST: {context:s} \n\nRESPONSE A:{hyp:s} \n\nRESPONSE B: .\n\n Which response is better? RESPONSE "
    inp = template.format(context=inpdict['context'], hyp=inpdict['hyp'])
    x = tokenizer([inp], return_tensors='pt').input_ids.to(device)
    outputs = model.generate(x, return_dict_in_generate=True, output_scores=True, max_new_tokens=1)
    return torch.exp(outputs.scores[0][:, 71]) / torch.exp(outputs.scores[0][:,:]).sum(axis=1).item() # index 71 corresponds to the token for 'A'

def score_ex_shp(ex, cfacts=None):
    score_a = float(get_reward_single({"context":ex['history'], "hyp":ex['human_ref_A']}, tokenizer, model))
    score_b = float(get_reward_single({"context":ex['history'], "hyp":ex['human_ref_B']}, tokenizer, model))
    print(ex['history'])
    print("REWARD: ", score_a, ", UPVOTES: ", ex['score_A'])
    print(ex['human_ref_A'])
    print("REWARD: ", score_b, ", UPVOTES: ", ex['score_B'])
    print(ex['human_ref_B'])
    if cfacts is not None:
        for counterfact in cfacts:
            score_counter = float(get_reward_single({"context":ex['history'], "hyp":counterfact}, tokenizer, model))
            print("REWARD: ", score_counter)
            print(counterfact)

def score_dialogue(row):
    cont = row['context'] +"\n"+"I was reading this information from a reliable source, and it got me thinking... "+row['src']
    print()
    print(row['hyp'])
    sco = float(get_reward_single({"context":cont , "hyp":row['hyp']}, tokenizer, model))
    print(sco)
    return sco

def score_all_dial(df):
    uns = df['context'].unique()
    for u in uns:
        sub = df[df['context']==u]
        print(u+"\n"+sub['src'].iloc[0])
        for i, rw in sub.iterrows():
            score_dialogue(rw)
            
def score_sum(row):
    cont = "Could someone help me summarize this passage? It's really confusing. \n"+row['src']
    # print("ref "+row['ref'])
    print(row['hyp'])
    sco = float(get_reward_single({"context":cont , "hyp":row['hyp']}, tokenizer, model))
    print(sco)
    return sco

def score_all_sum(df):
    uns = df['src'].unique()
    for u in uns:
        sub = df[df['src']==u]
        print(u)
        for i, rw in sub.iterrows():
            score_sum(rw)

# %%
dataset = load_dataset("stanfordnlp/shp", data_dir="askculinary")
# Out:
# Downloading and preparing dataset json/stanfordnlp--shp to /home/prasann/.cache/huggingface/datasets/stanfordnlp___json/stanfordnlp--shp-ee7c73b0d9a5ffc3/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e...
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/71.3M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.86M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.07M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /home/prasann/.cache/huggingface/datasets/stanfordnlp___json/stanfordnlp--shp-ee7c73b0d9a5ffc3/0.0.0/fe5dd6ea2639a6df622901539cb550cf8797e5a6b2dd7af1cf934bed8e233e6e. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dataset['test'][100]
# Out:
# {'post_id': 'kurnh7',
#  'domain': 'askculinary_test',
#  'upvote_ratio': 0.97,
#  'history': 'I\'m not a foodie, but my new wife is. Anything I can do to make spiral electric stove tops a better residential cooking experience? Are there replacement spiral stove tops that work better than others? Or is there an added accessory I can add to the stove top so that they work "better"?  We are renting in an apartment high-rise, so no chance of extending the gas lines and replacing the stove.',
#  'c_root_id_A': 'gitu316',
#  'c_root_id_B': 'gitsr4i',
#  'created_at_utc_A': 1610330988,
#  'created_at_utc_B': 1610330348,
#  'score_A': 122,
#  'score_B': 13,
#  'human_ref_A': 'I\'ve basically cooked on nothing but electric stoves (chronic renter) and really once you\'ve adjusted to the individual stove it\'s not that bad. A bit more juggling involved than on gas or induction but it\'s not as bad as the "gas or nothing" crowd make it seem.',
#  'human_ref_B': 'Get cast iron pans—I love to cook and my spirals work well. You just have to get used to it.',
#  'labels': 1,
#  'seconds_difference': 640.0,
#  'score_ratio': 9.3846153846}

# %%
def get_reward_comp(inpdict):
    template = "POST: {context:s} \n\nRESPONSE A:{hypa:s} \n\nRESPONSE B:{hypb:s} \n\n Which response is better? RESPONSE "
    inp = template.format(context=inpdict['context'], hypa=inpdict['hypa'], hypb=inpdict['hypb'])
    x = tokenizer([inp], return_tensors='pt').input_ids.to(device)
    outputs = model.generate(x, return_dict_in_generate=True, output_scores=True, max_new_tokens=1)
    return torch.exp(outputs.scores[0][:, 71]) / torch.exp(outputs.scores[0][:,:]).sum(axis=1).item() # index 71 corresponds to the token for 'A'

# %%
inp = """

I guess you could call this a shower thought but out of the blue I thought about this. How does our stomach acids not float up our throats in zero G? I’m not familiar with how our bodies work in space and would love to hear an explanation. (Directions for responder): Don't give a complicated answer, use short / simple vocabulary. 
"""
hypa = """
Your stomach acid isn't kept in your stomach only by gravity. (You can tell by the fact that you can do a handstand without throwing up.)

Instead, there's a valve called the lower esophageal sphincter that keeps your stomach contents in your stomach. ("Sphincter" is an anatomical word for "a muscular valve that can open and close"; the common usage of the word to mean the anal sphincter is more specific than the medical use.)
"""
hypa = "Basically, your stomach has a lid that opens when you swallow, but is closed the rest of the time."
hypb = """
There’s a tight muscular constriction called the lower esophageal sphincter (LES) at the junction of the esophagus and stomach. It normally keeps stomach contents from rising back up the esophagus.

The prevention of outflow from the stomach has exceptions, of course, in vomiting and acid reflux (heartburn or GERD). The vomiting reflex involves an autonomic relaxation of the sphincter. GERD (gastroesophageal reflus disease) results from weakness of the sphincter or structural defects in this area, such as a hiatal hernia in the diaphragm.
"""

get_reward_comp({'context':inp, 'hypa':hypb, 'hypb':hypa})
# Out:
# tensor([0.8602], device='cuda:1')

# %%
inp = "Write a paragraph. Say \"bat\" as much as possible." 
hypa = """
In the gloaming light, the nature enthusiast spotted a bat from a distance, darting haphazardly against the dusky backdrop of the evening sky. The bat, a creature of the night, was clearly on a mission. The bat was in search of its nightly sustenance, primarily consisting of insects, but some species of bat are known to consume fruits. Understanding the ecological importance of bats, the enthusiast was inspired to grab a baseball bat from his car and headed towards a nearby field to enjoy the cool evening breeze. His playful swings at the wind felt as graceful as the bat's agile movements above. As he engaged in this fun exercise, he spotted a large stone sculpture of a bat on the other end of the field. "What a peculiar town," he thought, "where the bat is so celebrated, from the realms of wildlife to the artistic expressions and even sports."
"""
hypb = """
In the gloaming light, the nature enthusiast spotted a frog from a distance, darting haphazardly against the dusky backdrop of the evening sky. The frog, a creature of the night, was clearly on a mission. The frog was in search of its nightly sustenance, primarily consisting of insects, but some species of frog are known to consume fruits. Understanding the ecological importance of frogs, the enthusiast was inspired to grab a baseball bat from his car and headed towards a nearby field to enjoy the cool evening breeze. His playful swings at the wind felt as graceful as the wood's agile movements above. As he engaged in this fun exercise, he spotted a large stone sculpture of a frog on the other end of the field. "What a peculiar town," he thought, "where the frog is so celebrated, from the realms of wildlife to the artistic expressions and even sports."
"""
get_reward_comp({'context':inp, 'hypa':hypb, 'hypb':hypa})
# Out:
# tensor([0.3274], device='cuda:1')

# %%
def gpt_template_even(row):
    template = "I'm drafting a response for this reddit post: {context:s} \n\n I'm considering 2 options:\n\n RESPONSE A:{human_ref_A:s} \n\nRESPONSE B: {human_ref_B:s}\n\n Which response is better, and why?"
    inp = template.format(context=row['history'], human_ref_A=row['human_ref_A'],human_ref_B=row['human_ref_B'] )
    return inp


def gpt_justify_gold(row, reverse=False):
    template = "I was looking at 2 responses to this reddit post: {context:s} \n\nThese were the 2 options I looked at:\n\nRESPONSE A: {human_ref_A:s} \n\nRESPONSE B: {human_ref_B:s}\n\n Why did response {goldresp:s} get more votes? Can you explain in detail why it wasn't the other response?"
    if row['score_A']>row['score_B']:
        gold = "A"
        if reverse:
            gold="B"
    else:
        gold = "B"
        if reverse:
            gold="A"
    inp = template.format(context=row['history'], human_ref_A=row['human_ref_A'],human_ref_B=row['human_ref_B'], goldresp=gold)
    return inp


print(gpt_justify_gold(dataset['test'][375]))
# Out:
# I was looking at 2 responses to this reddit post: What does coating bacon in flour do when you are baking bacon? My preferred method for cooking bacon in bulk is to use an oven-safe drying/cooling rack, and baking. I have seen a good amount of people insisting that coating bacon in flour makes for a better product. What exactly does coating bacon in flour prior to baking do? What are the benefits?
#
# These were the 2 options I looked at:
#
# RESPONSE A: My friend told me to do a 1:1 ratio with regular flour and rice flour when I asked her about this. I use about 1/2 cup total to dredge 1 package of Costco bacon. The bacon ends up so crispy with minimal shrinkage
#
# RESPONSE B: Absorbs and makes it crispy. I recommend skipping the flour and coating it in maple or brown sugar. It makes it crispy also. Candied bacon is best bacon.
#
#  Why did response A get more votes? Can you explain in detail why it wasn't the other response?

# %%
dataset['test'][375]
# Out:
# {'post_id': 'r0pzw0',
#  'domain': 'askculinary_test',
#  'upvote_ratio': 0.95,
#  'history': 'What does coating bacon in flour do when you are baking bacon? My preferred method for cooking bacon in bulk is to use an oven-safe drying/cooling rack, and baking. I have seen a good amount of people insisting that coating bacon in flour makes for a better product. What exactly does coating bacon in flour prior to baking do? What are the benefits?',
#  'c_root_id_A': 'hlvi65g',
#  'c_root_id_B': 'hlvby98',
#  'created_at_utc_A': 1637738327,
#  'created_at_utc_B': 1637734191,
#  'score_A': 10,
#  'score_B': 9,
#  'human_ref_A': 'My friend told me to do a 1:1 ratio with regular flour and rice flour when I asked her about this. I use about 1/2 cup total to dredge 1 package of Costco bacon. The bacon ends up so crispy with minimal shrinkage',
#  'human_ref_B': 'Absorbs and makes it crispy. I recommend skipping the flour and coating it in maple or brown sugar. It makes it crispy also. Candied bacon is best bacon.',
#  'labels': 1,
#  'seconds_difference': 4136.0,
#  'score_ratio': 1.1111111111}

# %%
ind = 100
score_ex_shp(dataset['test'][ind], 
     [
         "Get cast iron.",
         "I most humbly recommend that you acquire iron.",
         "Get cast bronze pans."
     ]
)
# Out:
# I'm not a foodie, but my new wife is. Anything I can do to make spiral electric stove tops a better residential cooking experience? Are there replacement spiral stove tops that work better than others? Or is there an added accessory I can add to the stove top so that they work "better"?  We are renting in an apartment high-rise, so no chance of extending the gas lines and replacing the stove.
# REWARD:  0.8530400395393372 , UPVOTES:  122
# I've basically cooked on nothing but electric stoves (chronic renter) and really once you've adjusted to the individual stove it's not that bad. A bit more juggling involved than on gas or induction but it's not as bad as the "gas or nothing" crowd make it seem.
# REWARD:  0.9150396585464478 , UPVOTES:  13
# Get cast iron pans—I love to cook and my spirals work well. You just have to get used to it.
# REWARD:  0.9483897686004639
# Get cast iron.
# REWARD:  0.9603092670440674
# I most humbly recommend that you acquire iron.
# REWARD:  0.892423689365387
# Get cast bronze pans.

# %%
# Out:
# ╭──────────────────────────── Traceback (most recent call last) ────────────────────────────╮
# │                                                                                           │
# │ /tmp/ipykernel_1196563/579212857.py:1 in <module>                                         │
# │                                                                                           │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_1196563/579212857.py'                │
# │ /tmp/ipykernel_1196563/3043354032.py:3 in gpt_template                                    │
# │                                                                                           │
# │ [Errno 2] No such file or directory: '/tmp/ipykernel_1196563/3043354032.py'               │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'inpdict' is not defined

# %%
ind = 229
score_sum(sums.loc[ind])
# Out:
# ref A coral reef, larger than the size of London, has been discovered for the first time, in the Amazon river, in Brazil.
# Scientists have been exploring a coral reef in the Amazon rainforest in Brazil.
# 0.9473028779029846
# 0.9473028779029846

# %%
score_all_sum(sums.loc[200:300])

# %%
faithdial = pd.read_csv("/mnt/data1/prasann/tfr-decoding/UniEval/faithdial.csv")

# %%
sums = pd.read_csv("/mnt/data1/prasann/tfr-decoding/UniEval/minitest.csv")

# %%
sums
# Out:
#       Unnamed: 0                                                src  \
# 0              0  KFC is seeking compensation of 1.5m yuan ($242...
# 1              1  KFC is seeking compensation of 1.5m yuan ($242...
# 2              2  KFC is seeking compensation of 1.5m yuan ($242...
# 3              3  KFC is seeking compensation of 1.5m yuan ($242...
# 4              4  KFC is seeking compensation of 1.5m yuan ($242...
# ...          ...                                                ...
# 996          996  The male bird, which was raised in a nest in F...
# 997          997  The male bird, which was raised in a nest in F...
# 998          998  The male bird, which was raised in a nest in F...
# 999          999  The male bird, which was raised in a nest in F...
# 1000        1000  The male bird, which was raised in a nest in F...
#
#                                                     ref  \
# 0     The fast food chain KFC is to sue three Chines...
# 1     The fast food chain KFC is to sue three Chines...
# 2     The fast food chain KFC is to sue three Chines...
# 3     The fast food chain KFC is to sue three Chines...
# 4     The fast food chain KFC is to sue three Chines...
# ...                                                 ...
# 996   Police have searched an estate after the disap...
# 997   Police have searched an estate after the disap...
# 998   Police have searched an estate after the disap...
# 999   Police have searched an estate after the disap...
# 1000  Police have searched an estate after the disap...
#
#                                                     hyp  coherence
# 0     Fast food giant KFC is suing three Chinese fir...   0.968118
# 1     Fast food giant KFC is suing three Chinese fir...   0.972529
# 2     Fast food giant KFC is suing three Chinese fir...   0.970681
# 3     Fast food giant KFC is suing three Chinese fir...   0.970684
# 4     Fast food giant KFC is suing three Chinese fir...   0.966887
# ...                                                 ...        ...
# 996   Police have said they are concerned for the we...   0.949536
# 997   Police have said they are concerned for the we...   0.949884
# 998   Police are concerned for the welfare of a whit...   0.935249
# 999   Police are concerned for the welfare of a whit...   0.944401
# 1000  Police say they are concerned for the welfare ...   0.951185
#
# [1001 rows x 5 columns]

# %%
score_dialogue(faithdial.loc[9])
# Out:
# Dylan's Candy Bar is a candy shop chain in New York City, East Hampton, Los Angeles, Chicago and Miami Beach.
# 0.6659116148948669
# 0.6659116148948669

# %%
score_all_dial(faithdial.loc[100:])
# Out:
# It is owned by Dylan Lauren, daughter of fashion designer Ralph Lauren.
# I love candy, what's a good brand?
#
# I am not sure, but I know that Dylan Lauren is the daughter of Ralph Lauren
# 0.2842506766319275
#
# I don't know about nougat, but Dylan Lauren is the daughter of Ralph Lauren.
# 0.5176063776016235
#
# No, they're owned by Dylan Lauren, daughter of Ralph Lauren.
# 0.5535995364189148
#
# No, I'm not sure, but Dylan Lauren, daughter of Ralph Lauren, is the owner.
# 0.3540433943271637
#
# No, but Dylan Lauren is the daughter of Ralph Lauren.
# 0.6500208973884583
#
# I don't know about nougat, but Dylan Lauren is the daughter of Ralph Lauren.
# 0.5176063776016235
#
# No, I am not sure. Did you know they are owned by Dylan Lauren, daughter of Ralph Lauren?
# 0.41521769762039185
#
# I don't know, but I know Dylan Lauren is the daughter of Ralph Lauren.
# 0.41414329409599304
#
# I am not sure but Dylan Lauren, daughter of Ralph Lauren, owns it.
# 0.2580575942993164
#
# I don't know about nougat but Dylan Lauren is the daughter of Ralph Lauren.
# 0.4697509706020355
#
# I'm not sure, but Dylan Lauren, daughter of Ralph Lauren, owns it.
# 0.3227522671222687
#
# I am not sure about nougat, but I know that Dylan Lauren is the daughter of Ralph Lauren.
# 0.37652862071990967
#
# I don't know but Dylan Lauren is the daughter of Ralph Lauren.
# 0.38014668226242065
#
# No, but I know Dylan Lauren is the daughter of Ralph Lauren.
# 0.4525162875652313
#
# No, I am not sure about nougat, but I know that Dylan Lauren is the daughter of Ralph Lauren
# 0.4277842044830322
#
# I can't say but Dylan Lauren is the daughter of Ralph Lauren.
# 0.3013259470462799
#
# I don't know about nougat but Dylan Lauren is the daughter of Ralph Lauren.
# 0.4697509706020355
#
# No, but Dylan Lauren is the daughter of Ralph Lauren.
# 0.6500208973884583
#
# I'm not sure, but Dylan Lauren is the daughter of Ralph Lauren.
# 0.35699576139450073
#
# I'm not sure but Dylan Lauren is their daughter, but she is also the daughter of Ralph Lauren.
# 0.23066683113574982
#
# I am not sure but I know that Dylan Lauren is the daughter of Ralph Lauren.
# 0.2650611698627472
#
# I can't say, but Dylan Lauren, the daughter of Ralph Lauren, owns it.
# 0.3630528151988983
#
# I can't say, but Dylan Lauren is the daughter of Ralph Lauren.
# 0.351051390171051
#
# I'm not sure, but Dylan Lauren is the daughter of Ralph Lauren.
# 0.35699576139450073
#
# I can't say but Dylan Lauren is the daughter of Ralph Lauren.
# 0.3013259470462799
#
# I don't know about nougat, but Dylan Lauren is the daughter of Ralph Lauren.
# 0.5176063776016235
#
# No, I don't know that but Dylan Lauren is the daughter of Ralph Lauren.
# 0.4907708764076233
#
# I don't have that information. However, I know that Dylan Lauren is the daughter of Ralph Lauren.
# 0.414788156747818
# Athletes in ancient Greece were advised to consume large quantities of meat and wine.
# I like to drink protein shakes before my workout.
#
# Interesting, did you know that ancient Greece was advised to consume large quantities of meat and wine?
# 0.7711586356163025
#
# I see. Do you like to consume meat and wine?
# 0.6900336146354675
#
# That's cool. Athletes were advised to consume large amounts of meat and wine.
# 0.7198867201805115
#
# Interesting. Did you know that ancient Greece advised athletes to consume large amounts of meat and wine?
# 0.7520778775215149
#
# Oh, that's interesting. Did you know that athletes were advised to consume large quantities of meat and wine?
# 0.7016193866729736
#
# In ancient Greece, athletes were advised to consume large quantities of meat and wine.
# 0.7810842990875244
#
# Yeah, in ancient Greece, athletes were advised to consume large amounts of meat and wine.
# 0.716514527797699
#
# I see, did you know that ancient Greek athletes were advised to consume large amounts of meat and wine?
# 0.7542415261268616
#
# Did you know that athletes were advised to consume large quantities of meat and wine?
# 0.8290398120880127
#
# Ah, that's cool. Did you know that athletes in ancient Greece were advised to consume large quantities of meat and wine?
# 0.7507337927818298
#
# Interesting, did you know athletes in ancient Greece were advised to consume large amounts of meat and wine?
# 0.7805453538894653
#
# I see, did you know that athletes in ancient Greece were advised to consume large quantities of meat and wine?
# 0.7493689060211182
#
# I see, so did you know athletes in ancient Greece were advised to consume large quantities of meat and wine?
# 0.778527557849884
#
# Interesting, did you know that ancient Greek athletes were advised to consume large amounts of meat and wine?
# 0.7790256142616272
#
# Oh, that's nice. Ancient Greek athletes were advised to consume large quantities of meat and wine.
# 0.7180020213127136
#
# Oh, that's nice. Did you know athletes in ancient Greece were advised to consume large quantities of meat and wine?
# 0.7623444199562073
#
# Yeah, there were a lot of ancient Greek athletes who had to eat large amounts of meat and wine.
# 0.6122474074363708
#
# Cool! Did you know athletes in ancient Greece were advised to consume large quantities of meat and wine?
# 0.7788615822792053
#
# Did you know that athletes in ancient Greece were advised to consume large quantities of meat and wine?
# 0.8365437984466553
#
# Interesting. Did you know that athletes were advised to consume lots of meat and wine?
# 0.718928873538971
#
# I see. Did you know that ancient Greek athletes were advised to consume large quantities of meat and wine?
# 0.7438700795173645
#
# Nice. Did you know athletes in ancient Greece were advised to consume large amounts of meat and wine?
# 0.8134443759918213
#
# I see. Did you know athletes in ancient Greece were advised to consume large amounts of meat and wine?
# 0.7447977662086487
#
# That's nice. Did you know athletes in ancient Greece were advised to consume large amounts of meat and wine?
# 0.7504755854606628
#
# In ancient Greece athletes were advised to consume large quantities of meat and wine.
# 0.7926415205001831
#
# Did you know that athletes in ancient Greece were advised to consume large amounts of meat and wine?
# 0.8341891765594482
#
# Cool, did you know that athletes were advised to consume large amounts of meat and wine in ancient Greece?
# 0.8137393593788147
#
# I see. In ancient Greece, athletes were advised to consume large amounts of meat and wine.
# 0.7185714840888977
#
# Cool! In ancient Greece athletes were advised to consume large amounts of meat and wine.
# 0.6965476870536804
#
# I see, so you like to consume a lot of meat and wine?
# 0.7703081965446472
#
# I see, did you know that ancient Greek athletes were advised to consume large amounts of meat and wine?
# 0.7542415261268616
#
# Yeah, and ancient Greek athletes were advised to consume large amounts of meat and wine.
# 0.7571618556976318
# A number of herbal concoctions and tonics have been used by strong men and athletes since ancient times across cultures to try to increase their strength and stamina.
# I like to drink protein shakes before my workout.
#
# Well, there are also herbal concoctions and tonics used by athletes and strong men.
# 0.3819064497947693
#
# That's cool! Some herbal concoctions and tonics have been used by athletes and strong men since ancient times.
# 0.4368836283683777
#
# I see, you know that a number of herbal concoctions and tonics have been used by athletes and strong men to increase their strength and stamina?
# 0.550499439239502
#
# Yes, and there are herbal tonics and concoctions used by athletes and strong men.
# 0.3361132740974426
#
# Yes, I see. Did you know that herbal concoctions have been used by athletes and strong men since ancient times? They use them to boost their strength and stamina However, did you know that?
# 0.496983140707016
#
# Interesting, there are herbal tonics and concoctions that are used by athletes and strong men in cultures to increase their strength.
# 0.3447611629962921
#
# Interesting. Do you use herbal concoctions or tonics? It is used by athletes and strong men across cultures!
# 0.3758384585380554
#
# That's great! Did you know that many herbal tonics and concoctions have been used by athletes and strong men since ancient times?
# 0.5515235066413879
#
# Well, the herbal tonics and concoctions have been used by athletes and strong men since ancient times.
# 0.46068045496940613
#
# Yes, some herbal tonics and concoctions have been used by strong men and athletes since ancient times.
# 0.4467507004737854
#
# Interesting. Did you know that herbs and tonics have been used by athletes and strong men since ancient times?
# 0.5418459177017212
#
# Oh really? There are herbal concoctions and tonics that are used by athletes and strong men to boost their strength and stamina.
# 0.5658856630325317
#
# Interesting. Did you know that a lot of herbal concoctions have been used to increase strength and stamina?
# 0.4331115782260895
#
# Interesting. Do you have herbal concoctions? They have been used by athletes and strong men since ancient times.
# 0.3473891019821167
#
# I see, what I know is that there are herbal tonics and concoctions used by athletes and strong men in ancient times. That's cool.
# 0.6625284552574158
#
# I see, did you know that a number of herbal concoctions and tonics have been used by strong men and athletes to increase their strength and stamina since ancient times?
# 0.5938788652420044
#
# It's interesting that strong men and athletes use herbal tonics and concoctions to increase their strength.
# 0.5245617628097534
#
# I see, I know that many herbal concoctions and tonics have been used by athletes and strong men for centuries
# 0.4381324350833893
#
# It seems people have been using herbal concoctions and tonics to increase their strength and stamina since ancient times.
# 0.45158082246780396
#
# I see, well a number of herbal concoctions and tonics have been used by athletes and strong men since ancient times.
# 0.5376839637756348
#
# Interesting, did you know that some herbal tonics and concoctions have been used to increase strength and stamina in cultures since ancient times?
# 0.5207687020301819
#
# Well, there are a number of herbal tonics and concoctions used by athletes and strong men since ancient times.
# 0.40493953227996826
#
# Have you tried herbal tonics? They have been used to boost strength and stamina.
# 0.3713710308074951
#
# Have you ever tried herbal concoctions? They are used by athletes and strong men.
# 0.3990269601345062
#
# I see, do you also know that herbal concoctions and tonics have been used by athletes and strong men since ancient times?
# 0.5405360460281372
#
# Well, herbal concoctions and tonics have been used by athletes and strong men since ancient times.
# 0.5163439512252808
#
# Interesting, did you know that there are herbal tonics and concoctions that have been used by strong men and athletes since ancient times?
# 0.5752127766609192
#
# Interesting, are you aware that herbal concoctions and tonics have been used by strong men and athletes since ancient times?
# 0.5313354730606079
#
# Cool, did you know that herbal concoctions and tonics have been used by athletes and strong men since ancient times?
# 0.7023229002952576
#
# I see, have you ever tried herbal concoctions? They are used to boost your strength and stamina Have you ever tried one?
# 0.547093391418457
#
# I see, did you know that herbal concoctions and tonics have been used to increase strength and stamina by strong men and athletes since ancient times?
# 0.6408336758613586
#
# I see, what about tonics and herbal concoctions that are used by athletes and strong men?
# 0.3809810280799866
# In the 1910s, Eugen Sandow, widely considered to be the first modern bodybuilder in the West, advocated the use of dietary control to enhance muscle growth.
# I like to drink protein shakes before my workout.
#
# Interesting. Did you know Eugen Sandow was the first modern bodybuilder? That is the 1900s Glad to know about that.
# 0.6062174439430237
#
# That's interesting. Did you know that Eugen Sandow advocated the use of dietary control in the 1910s?
# 0.6794236302375793
#
# I see, did you know that in the 1910s Eugen Sandow advocated the use of dietary control to enhance muscle growth?
# 0.7237643003463745
#
# Yeah, you may be interested to know that in the 1910s Eugen Sandow advocated using dietary control to increase muscle growth
# 0.8092914819717407
#
# Yes, in the 1910s, Eugen Sandow advocated using dietary control to enhance muscle growth.
# 0.7507914900779724
#
# I see, do you like dietary control to boost muscle growth?
# 0.6443831920623779
#
# Yes, Eugen Sandow was considered the first modern bodybuilder in the West.
# 0.6292401552200317
#
# Cool, did you know Eugen Sandow advocated the use of dietary control to enhance muscle growth? Do you like bodybuilding?
# 0.7215768694877625
#
# I see, did you know that Eugen Sandow was considered the first modern bodybuilder?
# 0.6725016236305237
#
# Yeah, did you know that Eugen Sandow, considered the first modern bodybuilder, advocated dietary control in the 1910s?
# 0.8209324479103088
#
# Do you think that Eugen Sandow was the first modern bodybuilder in the West?
# 0.5192498564720154
#
# Yes, Eugen Sandow advocated dietary control in the 1910s to increase muscle growth.
# 0.7565096616744995
#
# Oh, so you like to exercise? Another bodybuilder, Eugen Sandow, advocated dietary control for muscle growth.
# 0.7329474091529846
#
# Interesting, did you know that Eugen Sandow was considered the first modern bodybuilder in the West in the 1910s?
# 0.7517650723457336
#
# I see, did you know Eugen Sandow advocated dietary control to increase muscle growth in the 1910s?
# 0.7452325820922852
#
# I see, do you also like the fact that Eugen Sandow was considered the first modern bodybuilder in the West?
# 0.8453648090362549
#
# I see, did you know that Eugen Sandow was the first modern bodybuilder? He was widely considered the first modern bodybuilder in the West.
# 0.6241772174835205
#
# Yeah, Eugen Sandow was considered the first modern bodybuilder in the West in the 1910s.
# 0.6561082601547241
#
# Yes, I know that Eugen Sandow, considered the first modern bodybuilder in the West, advocated the use of dietary control.
# 0.7341830134391785
#
# Interesting, do you like the diet? It was also considered the first modern bodybuilder in the West in the 1910s
# 0.529535710811615
#
# Yes, in the 1910s Eugen Sandow advocated using dietary control to increase muscle growth.
# 0.7271442413330078
#
# I see, did you know Eugen Sandow was the first modern bodybuilder?
# 0.6985286474227905
#
# Cool, did you know Eugen Sandow was considered the first modern bodybuilder in the West?
# 0.7798005938529968
#
# Cool, do you want to follow Eugen Sandow's advice? He advocated using dietary control for muscle growth in the 1910s.
# 0.8360875844955444
#
# Cool, did you know that Eugen Sandow was considered the first modern bodybuilder in the West?
# 0.7662602066993713
#
# Cool! Did you know Eugen Sandow advocated dietary control in the 1910s?
# 0.7827447652816772
#
# Yes, in the 1910s, Eugen Sandow advocated the use of dietary control to increase muscle growth.
# 0.7312425971031189
#
# Yes, it is believed that Eugen Sandow advocated the use of dietary control for muscle growth.
# 0.4023374021053314
#
# Oh yes! In the 1910s, Eugen Sandow advocated the use of dietary control to enhance muscle growth.
# 0.6723544001579285
#
# Well, a bodybuilder from the 1910s advocated the use of dietary control to enhance muscle growth.
# 0.7844403386116028
#
# I see, well in the 1910s, Eugen Sandow was considered the first modern bodybuilder in the West to advocate the use of dietary control for muscle growth.
# 0.5870962738990784
#
# Yes, and also Eugen Sandow advocated dietary control to increase muscle growth.
# 0.37994712591171265
# Later, bodybuilder Earle Liederman advocated the use of ''beef juice'' or ''beef extract'' (basically, consomme) as a way to enhance muscle recovery.
# I like to drink protein shakes before my workout.
#
# Well, I know that bodybuilder Earle Liederman advocated the use of ''beef juice''
# 0.5842930674552917
#
# Well, he advocated using ''beef juice'' or ''beef extract'' as a way to improve muscle recovery.
# 0.478142648935318
#
# I don't know about others but I know that Earle Liederman advocated using "beef juice" or "beef extract" to boost muscle recovery.
# 0.23528549075126648
#
# Well, I know that Earle Liederman advocated the use of "beef juice"
# 0.55462646484375
#
# Well, Earle Liederman advocated using ''beef juice'' or ''beef extract'' to enhance muscle recovery.
# 0.5864557027816772
#
# Earle Liederman advocated the use of Beef juice as a way to enhance muscle recovery.
# 0.6372748613357544
#
# Earle Liederman advocated the use of Beef juice
# 0.5669702291488647
#
# Well, he advocated the use of "beef juice" or "beef extract" to improve muscle recovery.
# 0.4401358664035797
#
# Earle Liederman advocated the use of Beef juice as a way to enhance muscle recovery.
# 0.6372748613357544
#
# Earle Liederman advocated using "beef juice" or "beef extract" as a way to enhance muscle recovery.
# 0.65247642993927
#
# I'm not sure but Earle Liederman advocated the use of "beef juice" or "beef extract" to enhance muscle recovery.
# 0.24939872324466705
#
# I'm not aware of his name, but another bodybuilder called Earle Liederman advocated the use of ''beef juice''
# 0.4005237817764282
#
# Well, I know that Earle Liederman advocated the use of ''beef juice''
# 0.561103880405426
#
# I am not sure about that, but I know that Earle Liederman advocated the use of "beef juice" or "beef extract" I can't say.
# 0.1796637922525406
#
# Earle Liederman advocated the use of ''beef juice'' or ''beef extract'' as a way to enhance muscle recovery
# 0.5750577449798584
#
# He advocates using "beef juice" or "beef extract" to enhance muscle recovery.
# 0.5241963863372803
#
# I am not sure, but I know that bodybuilder Earle Liederman advocated using Beef juice, which was essentially beef extract and beef juice.
# 0.34945398569107056
#
# I'm not sure about the others but Earle Liederman advocated using Beef juice as a way to enhance muscle recovery.
# 0.3962397575378418
#
# Well, he advocated using beef juice or beef extract as a way to improve muscle recovery.
# 0.4393838346004486
#
# Well, I know that Earle Liederman advocated using Beef juice as a way to enhance muscle recovery
# 0.46994534134864807
#
# Well, I know that bodybuilder Earle Liederman advocated using "beef juice" as a way to enhance muscle recovery.
# 0.5745713114738464
#
# Earle Liederman advocated the use of ''beef juice'' or ''beef extract'' as a way to enhance muscle recovery
# 0.5750577449798584
#
# Well, he advocated the use of Beef juice as a way to enhance muscle recovery.
# 0.4008936285972595
#
# Well, I know that bodybuilder Earle Liederman advocated using "beef juice" as a way to enhance muscle recovery
# 0.5314852595329285
#
# I don't know of any but he advocated using Beef juice or Beef Extract as a way to enhance muscle recovery. It is just that Earle Liederman advocated Beef juice or Beef extract.
# 0.24650733172893524
#
# Earle Liederman advocated using ''beef juice'' or ''beef extract'' as a way to enhance muscle recovery.
# 0.6501027941703796
#
# Well, I know that Earle Liederman advocated the use of ''beef juice''
# 0.561103880405426
#
# Well, he advocated the use of "beef juice" or "beef extract" as a way to improve muscle recovery.
# 0.4547734260559082
#
# Well, I know that Earle Liederman advocated the use of ''beef juice'' or ''beef extract''
# 0.5320338606834412
#
# I don't know, but bodybuilder Earle Liederman advocated the use of "beef juice" as a way to enhance muscle recovery.
# 0.4709215462207794
#
# I'm not aware of any other bodybuilders, but I know that Earle Liederman advocated the use of "beef juice" or "beef extract" as a way to enhance muscle recovery.
# 0.22565923631191254
#
# Well, Earle Liederman advocated using Beef juice or Beef extract as a way to enhance muscle recovery.
# 0.4863230586051941
# In 1950s with recreational and competitive bodybuilding becoming increasingly popular Irvin P. Johnson began to popularize and market egg-based protein powders marketed specifically at bodybuilders and physical athletes.
# I like to drink protein shakes before my workout.
#
# I see, have you ever heard of the egg powders marketed specifically to bodybuilders?
# 0.39091652631759644
#
# Irvin P. Johnson began to popularize and market egg-based protein powders, which were marketed specifically at bodybuilders and physical athletes.
# 0.7264007329940796
#
# Irvin P. Johnson began to market and popularize egg-based protein powders at the time, for bodybuilders and physical athletes.
# 0.5032309293746948
#
# I don't know, but I know that in the 1950s Irvin P. Johnson began selling protein powders specifically for bodybuilders.
# 0.5997708439826965
#
# I see. In the 1950s Irvin P. Johnson began to popularize and market egg-based protein powders meant for bodybuilders and physical athletes.
# 0.6472772359848022
#
# I see, I know that Irvin P. Johnson started to sell egg-based protein powders, which were specifically marketed at bodybuilders and physical athletes.
# 0.6030063629150391
#
# I don't know about protein powders, but I know that in the 1950s Irvin P. Johnson began to market egg-based protein powders.
# 0.7008672952651978
#
# I'm not sure but Irvin P. Johnson started to sell egg-based protein powders in the 1950s. Its Irvin P. Johnson popularized and market them for bodybuilders and physical athletes.
# 0.439545601606369
#
# Irvin P. Johnson began marketing egg-based protein powders.
# 0.7025112509727478
#
# Is that the case? I know that Irvin P. Johnson began to market and popularize egg-based protein powders
# 0.263759970664978
#
# Is that so? I know that in the 1950s there was a new popular product called Irvin P. Johnson.
# 0.6300238370895386
#
# That's cool. I know that in the 1950s, Irvin P. Johnson began to sell egg-based protein powders.
# 0.7523607015609741
#
# I don't know about that but I know that in the 1950s Irvin P. Johnson started marketing egg-based protein powders and marketed specifically at bodybuilders
# 0.3243739604949951
#
# Interesting, in the 1950s Irvin P. Johnson started selling egg-based protein powders, specifically for bodybuilders and physical athletes
# 0.7874469757080078
#
# Irvin P. Johnson began selling egg-based protein powders, specifically to bodybuilders and physical athletes.
# 0.7260591983795166
#
# Is that so? Irvin P. Johnson started to sell egg-based protein powders, they were marketed specifically at bodybuilders and physical athletes.
# 0.4872893989086151
#
# Is that the case? I know that Irvin P. Johnson started popularizing and marketing egg-based protein powders.
# 0.21834537386894226
#
# Irvin P. Johnson started marketing egg-based protein powders for bodybuilders.
# 0.7124619483947754
#
# Interesting, I know that in the 1950s Irvin P. Johnson began marketing egg-based protein powders which were targeted at bodybuilders.
# 0.4934082329273224
#
# Interesting. Irvin P. Johnson began to popularize and market egg-based protein powders
# 0.552860677242279
#
# Irvin P. Johnson began selling egg-based protein powders in the 1950s.
# 0.7304103970527649
#
# Irvin P. Johnson began to popularize and market egg-based protein powders which were specifically marketed at bodybuilders.
# 0.6950328350067139
#
# In the 1950s Irvin P. Johnson started to market and popularize egg-based protein powders.
# 0.731107771396637
#
# That's good to know. In the 1950s Irvin P. Johnson began to market protein powders for bodybuilders and physical athletes.
# 0.56381756067276
#
# Is that so? Irvin P. Johnson started popularizing egg-based protein powders in the 1950s.
# 0.5392021536827087
#
# That's interesting. Irvin P. Johnson started selling egg-based protein powders for bodybuilders.
# 0.6695255041122437
#
# Interesting, did you know that Irvin P. Johnson began marketing and popularizing egg-based protein powders in the 1950s?
# 0.8302070498466492
#
# I see, did you know that in the 1950s Irvin P. Johnson started popularizing egg-based protein powders?
# 0.7695134878158569
#
# I see. Well I know that Irvin P. Johnson began selling egg-based protein powders to bodybuilders and physical athletes.
# 0.6291691660881042
#
# Well, did you know that in the 1950s Irvin P. Johnson began to popularize and market egg-based protein powders?
# 0.9001477956771851
#
# I am not sure but I know that in the 1950s Irvin P. Johnson started to popularize and market egg-based protein powders for bodybuilders.
# 0.2626214921474457
#
# I am not sure about the concentration but I know that in the 1950s Irvin P. Johnson began marketing and popularizing egg-based protein powders.
# 0.2831461727619171
# Green is the color between blue and yellow on the visible spectrum.
# My favorite color is green.  I love Money, green lights when i am driving, and the color of plants.  Green is fantastic!!!
#
# Cool, I know that green is between yellow and blue on the visible spectrum.
# 0.6544543504714966
#
# Cool, did you know that green is between yellow and blue on the visible spectrum?
# 0.7377621531486511
#
# Cool! Did you know that green is between yellow and blue on the visible spectrum?
# 0.6648833751678467
#
# I see, did you know green is the color between yellow and blue on the visible spectrum?
# 0.676171064376831
#
# Cool! Did you know that green is the color between yellow and blue on the visible spectrum?
# 0.6540722250938416
#
# Oh, cool! That's pretty interesting. I know that green is between yellow and blue on the visible spectrum. Cool!
# 0.43782541155815125
#
# Cool! Did you know that it is between yellow and blue on the visible spectrum?
# 0.5728471875190735
#
# Cool, what about the colors of plants and blue or yellow on the visible spectrum?
# 0.4280409812927246
#
# Cool! Did you know that it is between yellow and blue on the visible spectrum?
# 0.5728471875190735
#
# Cool, what about the color of plants? I know that green is between yellow and blue on the visible spectrum!
# 0.5786938667297363
#
# I see, have you ever heard of green? It is between yellow and blue on the visible spectrum.
# 0.4243178069591522
#
# I see, green is the color between yellow and blue on the visible spectrum.
# 0.6324965953826904
#
# Cool, have you ever been to Greenpoint, where it is between yellow and blue on the visible spectrum?
# 0.7652071714401245
#
# Cool! Green is the color between yellow and blue on the visible spectrum.
# 0.5013471245765686
#
# Cool, so you like the color between yellow and blue on the visible spectrum?
# 0.811385989189148
#
# Interesting, did you know that green is between yellow and blue on the visible spectrum?
# 0.6712214350700378
#
# I see, so you are a bot, you can't drive! Do you like green? It is between yellow and blue on the visible spectrum.
# 0.6174694895744324
#
# Cool! Do you also like the color of plants, as well? I know that green is between yellow and blue on the visible spectrum
# 0.40564340353012085
#
# Cool! Green is between yellow and blue on the visible spectrum.
# 0.5077230334281921
#
# I see, you know that green is the color between yellow and blue on the visible spectrum?
# 0.6346210241317749
#
# Oh, I see. Do you know about the color between yellow and blue on the visible spectrum?
# 0.4758303165435791
#
# Cool! Green is between yellow and blue on the visible spectrum. Cool!
# 0.6613973379135132
#
# Cool, did you know that green is between yellow and blue on the visible spectrum?
# 0.7377621531486511
#
# I see, do you like to drive between yellow and blue on the visible spectrum?
# 0.7610838413238525
#
# I see, green is between yellow and blue on the visible spectrum.
# 0.6393734812736511
#
# Cool! Green is the color between yellow and blue on the visible spectrum.
# 0.5013471245765686
#
# Cool! Green is between yellow and blue on the visible spectrum.
# 0.5077230334281921
#
# Interesting, did you know that green is the color between yellow and blue on the visible spectrum?
# 0.6574435830116272
#
# Oh, that's cool. It's also the color between yellow and blue.
# 0.5075084567070007
#
# Nice, did you know that green is between yellow and blue on the visible spectrum?
# 0.7482002377510071
#
# Cool! I know that green is between yellow and blue on the visible spectrum.
# 0.5652825236320496
#
# Cool! I know that green is between yellow and blue on the visible spectrum.
# 0.5652825236320496
# It is evoked by light which has a dominant wavelength of roughly 495570 nm.
# My favorite color is green.  I love Money, green lights when i am driving, and the color of plants.  Green is fantastic!!!
#
# Oh, I see. Did you know light has a dominant wavelength of 495570 nm?
# 0.7528409957885742
#
# That's interesting. It's the color of camouflage.
# 0.6398100256919861
#
# Well, I know that light has a dominant wavelength of about 495570 nm.
# 0.6510087251663208
#
# Interesting. It is evoked by light which has a dominant wavelength of roughly 495570 nm.
# 0.5941375494003296
#
# I see. It is evoked by light which has a dominant wavelength of 495570 nm.
# 0.7131435871124268
#
# I see. The dominant wavelength is 495570 nm.
# 0.674663782119751
#
# It's also the color of camouflage. It's a color that's evoked by light, which has a dominant wavelength of 495570 nm.
# 0.8210052251815796
#
# Yes, I know that light has a dominant wavelength of 495570 nm
# 0.7565505504608154
#
# Interesting, do you think that light has a dominant wavelength of 495570 nm? That is very cool.
# 0.7308992147445679
#
# Yes, it is evoked by light which has a dominant wavelength of roughly 495570 nm.
# 0.766373872756958
#
# Interesting, do you know that light has a dominant wavelength of about 495570 nm?
# 0.6450657844543457
#
# Oh yeah. It is evoked by light with a dominant wavelength of about 495570 nm.
# 0.7832086086273193
#
# It is also called camouflage because it is the color of Emeralds It has a dominant wavelength of 495570 nm.
# 0.7865003347396851
#
# Yes, it is also the color of camouflage.
# 0.8086513876914978
#
# Yes, I understand that it is the color of camouflage
# 0.7950124740600586
#
# It is evoked by light which has a dominant wavelength of roughly 495570 nm.
# 0.791815996170044
#
# Well, I know that light has a dominant wavelength of about 495570 nm.
# 0.6510087251663208
#
# Well, it's also evoked by light which has a dominant wavelength of about 495570 nm.
# 0.7662978172302246
#
# That's interesting. Did you know that light has a dominant wavelength of about 495570 nm?
# 0.643865704536438
#
# Oh, that's interesting. It's evoked by light with a dominant wavelength of 495570 nm.
# 0.6557630896568298
#
# Oh, and it is also called camouflage.
# 0.8257045745849609
#
# Yes, it is evoked by light which has a dominant wavelength of roughly 495570 nm.
# 0.766373872756958
#
# That's nice. It's evoked by light, which has a dominant wavelength of 495570 nm.
# 0.7122375965118408
#
# It is evoked by light with a dominant wavelength of about 495570 nm.
# 0.7400484085083008
#
# That's interesting. Have you ever seen light with a dominant wavelength of about 495570 nm?
# 0.6732751131057739
#
# Yes, the dominant wavelength is 495570 nm.
# 0.7251214385032654
#
# That's interesting. Have you ever heard of it? It's evoked by light that has a dominant wavelength of about 495570 nm. Have you ever heard of that?
# 0.3159258961677551
#
# Interesting. Light has a dominant wavelength of about 495570 nm.
# 0.6070559024810791
#
# It is evoked by light with a dominant wavelength of about 495570 nm.
# 0.7400484085083008
#
# I see, but I know that light has a dominant wavelength of 495570 nm.
# 0.6348969340324402
#
# Oh, that's interesting. Light has a dominant wavelength of about 495570 nm.
# 0.6281206011772156
#
# Oh, that's nice. Light has a dominant wavelength of 495570 nm. That's the wavelength of light that evokes it.
# 0.616206169128418
# Many creatures have adapted to their green environments by taking on a green hue themselves as camouflage.
# My favorite color is green.  I love Money, green lights when i am driving, and the color of plants.  Green is fantastic!!!
#
# Interesting, did you know that some creatures adapted to green environments by taking on a green hue themselves?
# 0.5694888830184937
#
# Yes, many creatures have adapted to their green environments by taking on a green hue themselves.
# 0.4928274154663086
#
# Yes, and it is also the color of the mona Lisa's dress, the benches in the house of commons, and the banner of Islam.
# 0.8253005146980286
#
# Interesting, did you know that some creatures have adopted green as camouflage?
# 0.5908578634262085
#
# Cool, do you know of the moon's dress? It's also the national color of Ireland.
# 0.7075225710868835
#
# It is also the national color of Ireland and also the dress that the Mona Lisa is wearing, among others.
# 0.8802111148834229
#
# Yes, many creatures have adapted to their green environments by taking on a green hue themselves, as camouflage
# 0.5760498046875
#
# Interesting, did you know that a lot of creatures are camouflaged by the green hue?
# 0.5470097064971924
#
# That's cool. Some creatures have taken on a green hue for camouflage.
# 0.4096905291080475
#
# Interesting. Did you know that many creatures have adapted to their green environments by taking on a green hue themselves?
# 0.528328537940979
#
# I see, well many creatures adapted to green environments by taking on a green hue themselves.
# 0.4310976266860962
#
# Yeah, it is the color of the banner of Islam.
# 0.5588403940200806
#
# Well, there are creatures that have taken on a green hue as camouflage as well.
# 0.3892931044101715
#
# I see, did you know that a lot of creatures are camouflaged with green hues?
# 0.5236682295799255
#
# Interesting, did you know that many creatures are also camouflaged in green hues like the Mona Lisa's dress?
# 0.8188803195953369
#
# Yeah, and the Mona Lisa wears a dress that is green.
# 0.8397873044013977
#
# Oh yeah? Many creatures have taken on a green hue as camouflage to suit their environments.
# 0.590628981590271
#
# I see, but other things are that many creatures have taken on a green hue themselves as camouflage.
# 0.36247602105140686
#
# Yes, many creatures have taken on a green hue themselves as camouflage, such as the Mona Lisa dress.
# 0.7215426564216614
#
# It is also the national color of Ireland
# 0.8887935280799866
#
# Yeah, and many creatures are adapted to green environments by taking on a green hue themselves as camouflage
# 0.6361151337623596
#
# It is also the national color of Ireland, and the dress that the Mona Lisa is wearing, as well as the benches in the house of commons.
# 0.8708329200744629
#
# Yeah, did you know that many creatures adapted to their green environments by taking on a green hue themselves?
# 0.6894668936729431
#
# Interesting. Did you know that many creatures have adapted to their green environments by taking on a green hue themselves?
# 0.528328537940979
#
# Well, a lot of creatures have adapted to green environments by taking on a green hue themselves.
# 0.4670027792453766
#
# Yes, many creatures have taken on green hues themselves as camouflage.
# 0.4703773558139801
#
# That's nice. Do you know any creatures that can camouflage themselves with green?
# 0.3565845787525177
#
# Interesting, there are creatures that take on a green hue themselves to camouflage.
# 0.3928278982639313
#
# Cool, do you know if they've adapted to the green environment by taking on a green hue as camouflage?
# 0.2945537865161896
#
# That's interesting. There are creatures that take on a green hue as camouflage, like the Mona Lisa's dress, the benches in the house of commons, and the banner of Islam.
# 0.6460527181625366
#
# I see, you know that many creatures have taken on a green hue themselves as camouflage?
# 0.5302559733390808
#
# Yes, it is also the national color of Ireland, the dress that the Mona Lisa is wearing, and the benches in the house of commons.
# 0.8343827128410339
#
# I'm not sure about the role but many creatures are able to adapt to green environments by taking on a green hue as camouflage.
# 0.20407232642173767
#
# Well, many creatures have adapted to their green environments by taking on a green hue themselves as camouflage.
# 0.5372858643531799
#
# Well, many creatures have taken on a green hue as camouflage, by putting themselves in the green shade.
# 0.5073854923248291
#
# I'm not sure, but many creatures have taken on a green hue to camouflage themselves.
# 0.3717047870159149
#
# Well, some creatures have adapted to their green environments by taking on a green hue themselves.
# 0.5508856773376465
#
# Some creatures have adapted to their green environments by taking on a green hue themselves as camouflage
# 0.6338817477226257
#
# Well, many creatures adapted to green environments by taking on a green hue themselves as camouflage Its
# 0.7504438161849976
#
# That is interesting. Many creatures have adapted to their green environments by taking on a green hue themselves. I don't know about that.
# 0.47997161746025085
#
# I am not sure but some creatures are green because they take on a green hue as camouflage.
# 0.46127983927726746
#
# I am not sure, but many creatures are able to take on a green hue by themselves as camouflage
# 0.3066849410533905
#
# I am not sure about that, but I know that many creatures have adapted to their green environments by taking on a green hue
# 0.296996533870697
#
# Well, many creatures have taken on a green hue themselves as camouflage They are adapted to their environments by taking on a green hue.
# 0.6823532581329346
#
# Well, many creatures have adapted to their green environments by taking on a green hue themselves as camouflage
# 0.5561556220054626
#
# Well, some creatures even adapted to their green environments by taking on a green hue themselves as camouflage.
# 0.5270096063613892
#
# Yes, and many creatures have taken on green hues themselves as camouflage.
# 0.42854177951812744
#
# I don't know but many creatures have adapted to their green environments by taking on a green hue.
# 0.472692608833313
#
# I don't know if they are important, but some creatures can even disguise themselves by taking on green hues as camouflage.
# 0.3493408262729645
#
# I don't know but many creatures have taken on a green hue themselves as camouflage, and have adapted to their environments.
# 0.3578163683414459
#
# I don't know about that, but many creatures have taken on green hues as camouflage to adapt to green environments.
# 0.27260980010032654
#
# Some creatures have taken on green hues as camouflage.
# 0.5677322149276733
#
# I don't know if it is, but many creatures have adapted to their green environments by taking on a green hue themselves.
# 0.4208853244781494
#
# I'm not sure. Some creatures have taken on green hues to camouflage. They have made a green hue themselves.
# 0.5313922762870789
#
# I am not sure, but some creatures take on green hues to camouflage themselves.
# 0.22621245682239532
#
# I'm not sure, but many creatures adapted to green environments by taking on a green hue themselves.
# 0.4391193687915802
#
# Some creatures adapted to their green environments by taking on a green hue themselves as camouflage
# 0.5694435834884644
#
# Yes, many creatures have taken on a green hue themselves as camouflage.
# 0.5130733847618103
#
# I don't know, but I know that some creatures have adopted green hues as camouflage as well Some animals have taken on the green hue themselves as camouflage, though.
# 0.2117026448249817
#
# I don't know about those, but many creatures have adapted to green environments by taking on green hue themselves.
# 0.3622605502605438
#
# I am not sure about the exact role but I know that some creatures are known for taking on a green hue as camouflage
# 0.14382512867450714
#
# I don't know if they do, but some creatures have adapted to their green environments by taking on a green hue as camouflage.
# 0.2651054859161377
#
# Yes, creatures that are green adapted to their environments by taking on a green hue as camouflage.
# 0.4862935245037079
#
# Yes, many creatures have adapted to their green environments by taking on a green hue themselves.
# 0.5287779569625854
# In the Middle Ages and Renaissance, green was the color commonly associated with merchants, bankers and the gentry, while red was reserved for the nobility.
# My favorite color is green.  I love Money, green lights when i am driving, and the color of plants.  Green is fantastic!!!
#
# Nice, the color was associated with merchants, bankers, and the gentry.
# 0.5026279091835022
#
# Oh, I see. It was often associated with merchants and bankers in the Middle Ages. That's nice.
# 0.5106726884841919
#
# Cool, did you know that green was associated with merchants in the Middle Ages and Renaissance?
# 0.7124544382095337
#
# Yes, in the Middle Ages and Renaissance, green was the color associated with merchants and bankers. Do you know any of these?
# 0.48333263397216797
#
# I see, green was associated with merchants and the gentry in the Middle Ages and Renaissance.
# 0.5428140759468079
#
# Nice, the color is commonly associated with merchants and bankers, while red is reserved for the nobility.
# 0.6412975192070007
#
# Cool, do you also like the color green? It was a color associated with merchants and bankers in the Middle Ages and Renaissance
# 0.37003350257873535
#
# Cool, did you know that it was also the color associated with merchants, bankers, and the gentry?
# 0.6830814480781555
#
# Green is the color most associated with spring, spring, nature, and the nobility, and also during the Middle Ages and Renaissance.
# 0.5720720887184143
#
# It's also a color that's associated with spring, nature, health, and hope. Cool, green was the color associated with merchants, bankers, and the gentry.
# 0.8405812978744507
#
# In the Middle Ages and Renaissance, green was commonly associated with merchants, bankers and the gentry.
# 0.7074956297874451
#
# That's nice. In the Middle Ages and Renaissance, green was often associated with merchants and bankers.
# 0.3438102900981903
#
# I see, what about if you like to see it more? Going back to the Middle Ages and Renaissance, green was associated with merchants, bankers, and the gentry.
# 0.3762679100036621
#
# Nice, did you know that green was used in the Middle Ages and Renaissance?
# 0.5752870440483093
#
# That's interesting. Did you know that in the Middle Ages and Renaissance, green was associated with merchants, bankers and the gentry? That's nice.
# 0.5673505663871765
#
# Green was the color most commonly associated with merchants, bankers and the gentry.
# 0.6513747572898865
#
# Yes, it was also used by merchants, bankers and the gentry in the Middle Ages and Renaissance.
# 0.44105014204978943
#
# Yes, green was associated with merchants, bankers, and the gentry. They were also associated with the nobility.
# 0.7089435458183289
#
# Interesting. Did you know that it was commonly associated with merchants and the gentry?
# 0.4298771321773529
#
# I see, so do you have some color history? It is associated with merchants, bankers and the gentry It was in the Middle Ages and Renaissance and red was reserved for the nobility. That's nice.
# 0.5571982264518738
#
# Yes, the color associated with merchants, banks and the gentry. Cool! I see, did you know that green was reserved for the nobility?
# 0.6134942770004272
#
# Oh yeah, it's the color most associated with spring. That's interesting. Did you know that in the Middle Ages and Renaissance, green was associated with merchants and the bankers.
# 0.5146191120147705
#
# I see, what I know about green is that it was associated with merchants and bankers
# 0.37428179383277893
#
# Cool, so did you know it was the color commonly associated with merchants and bankers in the Middle Ages and Renaissance? They were the nobility who preferred red.
# 0.832165002822876
#
# Yeah, it is the color most associated with spring, youth, and other things, as well. That is interesting. Do you like the color green? In the Middle Ages and Renaissance it was the color associated with merchants and bankers
# 0.37311723828315735
#
# In the Middle Ages and Renaissance, green was the color commonly associated with merchants and bankers, while red was reserved for the nobility.
# 0.7694694399833679
#
# It's been associated with merchants, bankers, and the gentry. It was also associated with gentry and gentry. It was even associated with people in the Middle Ages.
# 0.5650190114974976
#
# Cool! Did you know that green was the color commonly associated with merchants, bankers and the gentry?
# 0.6627692580223083
#
# Green was the color commonly associated with merchants, bankers and the gentry, while red was reserved for the nobility.
# 0.7757865190505981
#
# I see, green is a color commonly associated with merchants, banks and the gentry.
# 0.5991840958595276
#
# Cool, did you know that the colors in the Middle Ages and Renaissance were associated with merchants, bankers and the gentry?
# 0.7262081503868103
#
# I see, the color in the Middle Ages and Renaissance was associated with merchants and bankers and the gentry. I see.
# 0.6034367680549622
# By far the largest contributor to green in nature is chlorophyll, the chemical by which plants photosynthesize and convert sunlight into chemical energy.
# My favorite color is green.  I love Money, green lights when i am driving, and the color of plants.  Green is fantastic!!!
#
# Well, chlorophyll is the chemical by which plants convert sunlight into chemical energy.
# 0.41273033618927
#
# In the US, chlorophyll is a chemical that plants use to convert sunlight into chemical energy.
# 0.7673431038856506
#
# Cool, what about chlorophyll? It is the chemical by which plants convert sunlight into chemical energy.
# 0.4475419521331787
#
# Well, the largest contributor to green is chlorophyll, the chemical that converts sunlight into chemical energy.
# 0.5885550379753113
#
# Yes, and by far the biggest contributor to green in nature is chlorophyll, the chemical by which plants photosynthesize and convert sunlight into chemical energy.
# 0.5909119248390198
#
# I see, I know that chlorophyll is the chemical by which plants convert sunlight into chemical energy.
# 0.5100829601287842
#
# I see, do you like to know that the chemical that converts sunlight into energy is chlorophyll?
# 0.575238823890686
#
# Interesting, have you heard of chlorophyll? It's the chemical that plants use to convert sunlight into chemical energy. Have you heard of the Green Party?
# 0.5151058435440063
#
# It's also considered green in nature. What do you think of chlorophyll?
# 0.28731241822242737
#
# Well, the biggest contributor to green in nature is chlorophyll.
# 0.6178579330444336
#
# I see. By far the biggest contributor to green is chlorophyll, the chemical by which plants photosynthesize and convert sunlight into chemical energy.
# 0.6009805798530579
#
# That's cool! One thing I know about chlorophyll is that it converts sunlight into chemical energy.
# 0.34298503398895264
#
# Yeah, it's also known as chlorophyll, which is a chemical that converts sunlight into energy.
# 0.46600764989852905
#
# It's also the chemical by which plants convert sunlight into energy.
# 0.5230384469032288
#
# The largest contributor to green in nature is chlorophyll.
# 0.7307575345039368
#
# That's cool! I know that chlorophyll is the chemical that converts sunlight into energy by plants. That chemical is called chlorophyll.
# 0.4348054826259613
#
# I see, have you ever heard of chlorophyll? It's the chemical that plants use to convert sunlight into energy.
# 0.4536088705062866
#
# I see, do you know that chlorophyll is the biggest contributor to green in nature?
# 0.49903202056884766
#
# It is a chemical by which plants photosynthesize and convert sunlight into chemical energy.
# 0.5453066229820251
#
# Yes, the biggest contributor to green is chlorophyll, which is the chemical that converts sunlight into chemical energy.
# 0.526176929473877
#
# So do you agree with the Green Party? They're famous for promoting environmental protection and social justice.
# 0.7870820760726929
#
# Well, they also do a lot of greening in nature by converting sunlight into chemical energy.
# 0.39272257685661316
#
# I see. By far the biggest contributor to green is chlorophyll.
# 0.6196644306182861
#
# It's the chemical by which plants convert sunlight into chemical energy.
# 0.479489266872406
#
# Oh, cool. By far the biggest contributor to green is chlorophyll, the chemical by which plants photosynthesize and convert sunlight into chemical energy.
# 0.6511868238449097
#
# So, I know that chlorophyll is the most contributor to green in nature
# 0.6287280917167664
#
# Cool, do you think chlorophyll is the largest contributor to green in nature? Do you think so?
# 0.3569129407405853
#
# I see. And a large part of the green in nature is chlorophyll.
# 0.47512173652648926
#
# Interesting. In the US, they advocate environmental protection and social justice.
# 0.31490960717201233
#
# Interesting. There is also chlorophyll, which is the chemical by which plants convert sunlight into chemical energy.
# 0.2769642174243927
#
# Cool, so did you know that chlorophyll is the biggest contributor to green in nature?
# 0.724303662776947
#
# In the USA, green is a chemical that plants use to convert sunlight into chemical energy.
# 0.8662161231040955
#
# Oh, cool. It's that chemical that converts sunlight into chemical energy. Cool.
# 0.6532115936279297
#
# That's cool! I know that chlorophyll is the most equivable contributing to green in nature.
# 0.3366406261920929
#
# ...
# 0.7082982659339905
#
# Cool, snowflakes get to stay around particles and then get cooled, and they freeze in hexagonal-shaped crystals.
# 0.4950759708881378
#
# Cool! Snowflakes can numb particles in the atmosphere by attracting supercooled water droplets, which freeze in hexagonal-shaped crystals.
# 0.537226140499115
#
# Do you also like the way snowflakes swarm around particles in the atmosphere?
# 0.5783352851867676
#
# Cool, Snowflakes nucleate around particles in the atmosphere by attracting supercooled water droplets.
# 0.6167941689491272
#
# Ah, did you know snowflakes swarm around particles in the atmosphere? They do so by attracting supercooled water droplets, which freeze in hexagonal-shaped crystals.
# 0.7113017439842224
#
# Well, I know that snowflakes are attracting supercooled water droplets. They then freeze in hexagonal-shaped crystals.
# 0.595210075378418
#
# Neat, Snowflakes nucleate around particles in the atmosphere by attracting supercooled water droplets, which freeze in hexagonal-shaped crystals.
# 0.6181574463844299
#
# Cool, so you like to see snowflakes nucleate around particles in the atmosphere?
# 0.6976456046104431
#
# Cool! Snowflakes nucleate around particles in the atmosphere by attracting supercooled water droplets, which freeze in hexagonal-shaped crystals.
# 0.6264665722846985
#
# Neat! Did you know snowflakes nucleate around particles in the atmosphere by attracting supercooled water droplets?
# 0.6610370874404907
#
# Interesting, do you like to see snowflakes floating around particles in the atmosphere?
# 0.4634097218513489
#
# I see, so you are like the guy who has snowflakes? These snowflakes go round particles in the atmosphere and then they can spawn supercooled water droplets, which freeze in hexagonal-shaped crystals.
# 0.773486316204071
#
# Cool, snowflakes nucleate around particles in the atmosphere by attracting supercooled water droplets.
# 0.710927426815033
#
# Cool, snowflakes eat up particles in the atmosphere by attracting supercooled water droplets. They then freeze in hexagonal-shaped crystals.
# 0.7192360162734985
#
# That's cool! Snowflakes are actually nucleated around particles in the atmosphere.
# 0.6799117922782898
#
# That's nice. Snowflakes nucleate around particles in the atmosphere.
# 0.5443405508995056
#
# Cool! Snowflakes can then go into the atmosphere to attract supercooled water droplets, which freeze in hexagonal-shaped crystals.
# 0.3623040020465851
#
# I see, do you have any tips on how to get a supercooled water droplet? They 'cause they are attracting supercooled water droplets.
# 0.6910173296928406
#
# Oh, did you know that snowflakes nucleate around particles in the atmosphere by attracting supercooled water droplets?
# 0.7732711434364319
#
# Do you mean the water droplets that freeze? Do you like to nucleate around particles in the atmosphere?
# 0.5318467020988464
#
# Interesting, did you know that snowflakes nucleate around particles in the atmosphere by attracting supercooled water droplets?
# 0.6379383206367493
#
# Do you have snowflakes? They nucleate around particles in the atmosphere.
# 0.3857906758785248
#
# Ah, snowflakes? I see. They nucleate around particles in the atmosphere by attracting supercooled water droplets.
# 0.7689663767814636
#
# That's nice! Snowflakes nucleate around particles in the atmosphere by attracting supercooled water droplets.
# 0.4858810305595398
#
# Cool! Did you know that snowflakes can be shaped hexagonal shaped crystals?
# 0.5481107234954834
#
# Cool, did you know snowflakes nucleate around particles in the atmosphere by attracting supercooled water droplets?
# 0.7247315049171448
#
# Interesting, do you also like the crystals that freeze in hexagonal shapes when you fall in the snow?
# 0.6958888173103333
#
# Do you know that snowflakes attract supercooled water droplets?
# 0.5382023453712463
#
# Well, Snowflakes nucleate around particles in the atmosphere by attracting supercooled water droplets, which freeze in hexagonal-shaped crystals.
# 0.4340525269508362
#
# Interesting, have you heard of snowflakes? They can also be found in the atmosphere in hexagonal-shaped crystals.
# 0.36558768153190613
#
# Oh, so that's nice. Snowflakes nucleate around particles in the atmosphere.
# 0.6181010603904724
# Complex shapes emerge as the flake moves through differing temperature and humidity zones in the atmosphere, such that individual snowflakes differ in detail from one another, but may be categorized in eight broad classifications and at least 80 individual variants.
# I love winter season becuase it is so beautiful when the snow covers the parks!
#
# Oh, that's cool. Well, they also have complex shapes, like how the flake moves through different temperature and humidity zones.
# 0.3313593864440918
#
# Oh, that's interesting. The fact that each snowflake differs in detail is that they can be classified in 8 broad classifications.
# 0.5534118413925171
#
# Oh I see. They have complex shapes as they move through different zones of temperature and humidity.
# 0.5840686559677124
#
# They are also made of complex shapes, as the flake moves through different temperature and humidity zones in the atmosphere. There are eight broad classifications of snowflakes, with at least 80 individual variants.
# 0.42698797583580017
#
# I see, that's interesting. Have you ever heard of the fact that they can be classified in eight broad classifications?
# 0.5454118251800537
#
# I see. I know that individual snowflakes can have at least 80 individual variants and 8 broad classifications.
# 0.681121826171875
#
# Yeah, and they have a complex shape as the flake moves through different temperatures and humidity zones.
# 0.33635538816452026
#
# Cool, do you like complex shapes? They are formed in eight broad classifications. Its At least 80 different variants of each of them.
# 0.5159444212913513
#
# Yeah, they also vary in size as they move through different temperature and humidity zones.
# 0.48127368092536926
#
# Oh, that's nice. They can be categorized in 8 broad classifications and at least 80 individual variants.
# 0.6110067963600159
#
# Interesting, but I know that they can be categorized in eight broad classifications They can also be found in at least 80 individual variants They can be classified into eight broad classifications Perhaps a one, but that they can be categorized into eight broad classifications
# 0.6337885856628418
#
# That's interesting. They can be classified in eight broad classifications and at least 80 individual variants.
# 0.6199516654014587
#
# The fact that each snowflakes can be classified in 8 broad classifications and at least 80 individual variants.
# 0.825976550579071
#
# That's interesting. The snowflakes vary in detail but are classified in eight broad classifications.
# 0.5852705240249634
#
# Interesting, did you know that the flake's shape is complex? As it moves through different temperature and humidity zones in the atmosphere, individual snowflakes differ in detail from one another.
# 0.5745031833648682
#
# I see, have you heard of complex shapes? These forms are formed when the flake moves through different temperature and humidity zones in the atmosphere.
# 0.48861145973205566
#
# I see. So are you aware that different temperatures and humidity zones in the atmosphere make for complex shapes? They can be categorized in 8 broad classifications or 80 individual variants.
# 0.5031759738922119
#
# Yes, they are categorized in eight broad classifications and at least 80 individual variants.
# 0.6525870561599731
#
# Interesting. It is also interesting to know that there are at least 80 individual variants of the shapes. As the flake moves through different temperatures and humidity zones in the atmosphere.
# 0.4858090579509735
#
# That's interesting, but they can be categorized in 8 broad classifications, and have at least 80 individual variants.
# 0.4879816174507141
#
# The snowflakes are categorized in eight broad classifications and at least 80 individual variants, so they differ in detail from one another.
# 0.6281589269638062
#
# I see. Did you know that they are categorized in eight broad classifications and at least 80 individual variants?
# 0.6535046696662903
#
# I see, do you like a complex shape? That is due to the fact that each snowflakes is different from the next, but in eight broad classifications and 80 individual variants.
# 0.5052322149276733
#
# They can be classified in eight broad classifications and at least 80 individual variants.
# 0.6957470178604126
#
# Interesting. Do you know that complex shapes emerge as the flake moves through different temperature and humidity zones?
# 0.23872950673103333
#
# I see, have you ever heard of the structure of the flake? It is complicated.
# 0.5385594964027405
#
# Interesting, are you aware that different variations are formed in different temperatures and humidity zones in the atmosphere? That is interesting, although each individual snowflakes differ in detail from one another, but they can be classified in 8 broad classifications and 80 individual variants
# 0.3785456418991089
#
# Interesting. They are categorized in eight broad classifications and 80 individual variants.
# 0.5744810700416565
#
# That's interesting. Do you like the complex shapes that individual snowflakes can have? They can have 8 broad classifications and at least 80 individual variants.
# 0.6778042316436768
#
# I see, do you know that they can be categorized in eight broad classifications or 80 individual variants?
# 0.4889342784881592
#
# Well, they can have a lot of variations as well. They can be categorized in eight broad classifications and at least 80 individual variants.
# 0.38338133692741394
#
# The shape of each snowflakes differs greatly from each other because of different temperatures and humidity.
# 0.4093233346939087
# Human clothing, such as a hat or scarf, may be included.
# I love winter season becuase it is so beautiful when the snow covers the parks!
#
# That's nice! Did you know that human clothing such as a hat or scarf can be included?
# 0.45179498195648193
#
# Oh I see, do you like to wear human clothing like a hat or scarf?
# 0.6087488532066345
#
# Interesting, human clothing, like a hat or scarf, can be included too.
# 0.5379372835159302
#
# Ah, and can include human clothing like a hat or scarf.
# 0.4616270363330841
#
# I see, I know that things like a hat or scarf can be included as well.
# 0.5994076132774353
#
# Interesting. Human clothing, like a hat or scarf, can be included.
# 0.42190656065940857
#
# Neat! Did you know that you can wear human clothing? It can be a hat or scarf
# 0.532927930355072
#
# Cool! Human clothing, like a hat or scarf, can be included.
# 0.4265340268611908
#
# Interesting. Did you know that a scarf or hat is also human clothing?
# 0.5839394927024841
#
# Interesting, did you know that some people have clothing like a hat or scarf?
# 0.46546438336372375
#
# Cool, do you like to wear human clothing?
# 0.5247024297714233
#
# Cool, do you also wear clothing that is human? Perhaps a hat or scarf.
# 0.5448050498962402
#
# Cool, if you are wearing something like a hat or scarf, it can be included.
# 0.49778497219085693
#
# Interesting. Have you ever tried human clothing like a hat or scarf?
# 0.36628401279449463
#
# Well, people can also have a costume or scarf, which is a human clothing.
# 0.45581862330436707
#
# Cool, have you ever thought to include something like a scarf or hat?
# 0.5824859142303467
#
# That's awesome! Some human clothing, like a hat or scarf, can be included. Have you ever been to the Olympics?
# 0.5668120980262756
#
# Interesting. Have you ever worn a hat or scarf?
# 0.44325774908065796
#
# Yeah, a scarf or hat can be included.
# 0.5659325122833252
#
# Well, human clothing such as a hat or scarf can be included, too.
# 0.517623782157898
#
# Interesting, do you like wearing something other than a hat or scarf as well? Cool!
# 0.5977816581726074
#
# Do you have human clothing? It's a hat or scarf.
# 0.5114777684211731
#
# Yeah, it can be a human hat or scarf.
# 0.51948481798172
#
# Cool! Also, you can wear something like a hat or scarf in your snowmen.
# 0.6455628275871277
#
# Interesting, I know that people can have things like a hat or scarf as well.
# 0.4345638155937195
#
# Nice, I know that some human clothing, like a hat or scarf, can be included
# 0.4275101125240326
#
# Yes, people can also have human clothing, like a hat or scarf. That's cool!
# 0.5616175532341003
#
# Yeah, if you want to include human clothing, like a hat or scarf, then you can do so.
# 0.6309407949447632
#
# Do you have any human clothing, like a hat or scarf?
# 0.44139760732650757
#
# I see, are you a human? Some items like a hat or scarf can be included
# 0.3052700161933899
#
# Oh, that's nice! Have you ever worn human clothing? It can be a hat or scarf.
# 0.5616670250892639
#
# Do you wear human clothing? As well as a hat or scarf.
# 0.46554648876190186
# This can be done for a variety of reasons, including exercise, leisure, traveling, and various sports.
# I love winter season becuase it is so beautiful when the snow covers the parks!
#
# I see, what I know is that ice skating, toboganning and ice fishing are all winter activities
# 0.6895891427993774
#
# I see, winter is a good time to do things like exercise, leisure, traveling and many more.
# 0.6074498891830444
#
# Oh, I see. I know that you can do it for a variety of reasons, like leisure, for exercise, for vacation, or for different sports.
# 0.6299607157707214
#
# Do you go to an activity like ice skating, toboganning, or fishing?
# 0.7651383876800537
#
# Do you do anything for exercise, leisure, traveling, or other things?
# 0.22337418794631958
#
# Yes, there are many reasons to do this, including toboganning and skiing.
# 0.6013747453689575
#
# Yeah, and there are many things to do in the winter, like ice skating, toboganning and other activities.
# 0.8041971921920776
#
# Cool, so you can go ice skating, toboganning, and fishing in winter?
# 0.65643709897995
#
# Do you do ice skating, toboganning or fishing?
# 0.7001612782478333
#
# Well, the winter is great for exercise, traveling, and more!
# 0.4440234899520874
#
# Interesting, I know that winter can be done for a variety of reasons. Is that a good thing?
# 0.4540233314037323
#
# I see, you can also go for a variety of reasons like leisure, travel, or exercise
# 0.37258443236351013
#
# Yes, it can be done for a variety of reasons, including exercise, leisure, traveling, and sports.
# 0.430687814950943
#
# Cool, did you know that winter activities can be done for many reasons?
# 0.6324867010116577
#
# Do you like to go ice skating? Do you like to travel?
# 0.6469192504882812
#
# That's interesting, there are activities such as toboganning and fishing.
# 0.6359112858772278
#
# I see, what I know is that you can do things such as ice skating, toboganning and ice fishing senzati senzati senzati I'm not sure about that.
# 0.6414210200309753
#
# Oh, so you like to go to the ice rink, for example?
# 0.784009575843811
#
# I see, and you can also go ice skating and toboganning senzati
# 0.5578141212463379
#
# I see, did you also know there are activities for various reasons like leisure, exercising, traveling and more?
# 0.494035005569458
#
# Ah, so you like ice skating, or toboganning, or going to ice fishing?
# 0.833945631980896
#
# Well, there are many things you can do in winter like leisure, exercise, and sports.
# 0.4796804189682007
#
# Well, there are also activities like toboganning, ice fishing and other activities.
# 0.8219527006149292
#
# I see, well there are many activities in winter like skiing, toboganning and fishing.
# 0.8080958127975464
#
# Ah, ice skating, toboganning and ice fishing. That's cool!
# 0.7639340162277222
#
# That's nice. It can be done for a variety of reasons, like exercise, leisure, or travel.
# 0.36000311374664307
#
# Ah, so you can do activities like toboganning and ice fishing.
# 0.8305037617683411
#
# Yes, winter can be done for various reasons.
# 0.43817782402038574
#
# There are a variety of activities to do, like leisure, exercise, and other things.
# 0.35237282514572144
#
# I see, and it can be done for many reasons, such as exercise and leisure, and also travel and for various sports.
# 0.4848071038722992
#
# It can be done for many reasons, like exercise, leisure, traveling, and other things.
# 0.5037227272987366
#
# I see, do you do anything besides exercising?
# 0.5655152797698975

# %%
input_text = "POST: Instacart gave me 50 pounds of limes instead of 5 pounds... what the hell do I do with 50 pounds of limes? I've already donated a bunch and gave a bunch away. I'm planning on making a bunch of lime-themed cocktails, but... jeez. Ceviche? \n\n RESPONSE A: Lime juice, and zest, then freeze in small quantities.\n\n RESPONSE B: .\n\n Which response is better? RESPONSE"
x = tokenizer([input_text], return_tensors='pt').input_ids.to(device)
outputs = model.generate(x, return_dict_in_generate=True, output_scores=True, max_new_tokens=1)
torch.exp(outputs.scores[0][:, 71]) / torch.exp(outputs.scores[0][:,:]).sum(axis=1).item() # index 71 corresponds to the token for 'A'

# %%
cont = "I want to make a great chicken dish for my son-in-law, but I only have 2 days, what should I make?"
hyp = "You should do orange chicken. It's chewy, flavorful, and only takes a couple of hours to make."
get_reward({"context":cont, "hyp":hyp}, tokenizer, model)
